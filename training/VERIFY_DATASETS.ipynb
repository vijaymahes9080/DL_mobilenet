# %% [markdown]
# # 💎 ORIEN: Neural Data Audit
# **Version**: 1.0
#
# Run this to verify the integrity of all neural shards.

# %%
import os, sys
from pathlib import Path
ROOT = Path('.').absolute()
if (ROOT / 'scripts').exists():
    sys.path.append(str(ROOT))

from scripts.verify_datasets import check_all
check_all()
