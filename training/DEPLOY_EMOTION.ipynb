# %% [markdown]
# # 💎 ORIEN: Emotion Dataset Deployment
# **Source**: FER2013 CSV
# **Target**: Images in `dataset/face_emotion/train/`

# %%
import os, sys
from pathlib import Path
ROOT = Path('.').absolute()
if (ROOT / 'scripts').exists():
    sys.path.append(str(ROOT))

from scripts.deploy_emotion_images import deploy
deploy()
